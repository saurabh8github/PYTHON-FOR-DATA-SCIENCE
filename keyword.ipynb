# %%
#function with unknown argument
def greet(*name):
  print("functio with unkonwn arg0")
  print('hello',name[0],name[1])
greet('raju','billi','tomi')
# Out:
# functio with unkonwn arg0
# hello raju billi

# %%
#creat a user define function to
