# %%
#Creation of List
#Creating Blank List
print("Blank List: ")
L = []
print(L)
# Out:
# Blank List:
# []

# %%
# Creating a List of numbers and strings
print("\nList of numbers and srings: ")
L = [10, "Pen", 20, 14, "Copy", "Paper"]
print(L)
# Out:
# List of numbers and srings:
# [10, 'Pen', 20, 14, 'Copy', 'Paper']

# %%
# Creating a Multi-Dimensional List
# (By Nesting a list inside a List)
print("\nMulti-Dimensional List: ")
L = [['Table', 'Chair'], ['Fan']]
print(L)
# Out:
# Multi-Dimensional List:
# [['Table', 'Chair'], ['Fan']]
